# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0558/vitbmleda-1/blob/master/Copy_Of_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploring Data: I took data from online source"https://www.kaggle.com/raghu07/ipl-data-till-2017" which has 150451 rows ×
# 48 columns.The variable are :
#
#
#
# *  MatcH_id - Uniquely identifies a match
# *  Over_id - Identifies an over in an innings
# *  Ball_id - Identifies a ball in an over
# *  Innings_No - A period during which a person or group is active                  or effective.
# *   Extra_Type - Type of extra(wide,noball,byes...)
# *  Runs_Scored - Runs Scored by batsman in a that ball
# *  Extra_runs - Extra runs scored by the bats man
# *   Wides - a ball that is judged to be too wide of the stumps for             the batsman to play, for which an extra is awarded to               the batting side.
# *   Legbyes -  If a ball delivered by the bowler first strikes the                 person of the striker, runs shall be scored only                  if the umpire is satisfied that the striker has
# *   Byes -  In a tournament, the preferential status of a player               or team not paired with a competitor in an early round             and thus automatically advanced to play in the next                 round
# *   Noballs - This means the batsman can freely hit one ball with                 no danger of being out in most ways. No-balls due                  to overstepping the crease are not uncommon,                     especially in short form cricket, and fast bowlers                tend to bowl them more often than spin bowlers.
# *   Penalty - a punishment imposed for breaking a law, rule, or                  contract.
# *  Bowler_Extras -  Only runs scored from the bat count to the                        batsman, but to the side's score may be added                        the following extras: ... If a bowler                             delivers a complete over without a run being                      scored from the bat (even though the opponents                        may have scored extras by means of byes or                         leg byes), he has achieved a maiden over.
# *   Out_type - How batsman got Out
# *   Run_out - A run out is when the batsmen are going for a run or               runs, but fall short of the batting crease when the                stumps are broken by the fielding team. The batsman                  must have some part of his bat or body grounded                  beyond the crease - on the line would be out.
# *   LBW - The definition of leg before wicket (lbw) is currently             Law 36 in the Laws of Cricket, written by the Marylebone             Cricket Club (MCC). Before a batter can be dismissed         lbw, the fielding team must appeal to the umpire.
#
# *   Match_Date - Date on which match played
# *   Fielders - A fielder is a player in cricket, baseball, or                     rounders who is fielding or one who has a                           particular skill at fielding. The fielders crouch                  around the batsman's wicket.
#
# *   Bowler - Bowling, in cricket, is the action of propelling the                  ball toward the wicket defended by a batter. A                   player skilled at bowling is called a bowler; a                  bowler who is also a competent batter is known as an               all-rounder.
# *  Striker_match_SK - Surrogate Key from Player_match Dimension
# *  StrikerSK - Surrogate Key from Player Dimension
# *    NonStriker_match_SK - Surrogate Key from Player_match                                    Dimension
# *  Fielder_match_SK - Surrogate Key from Player_match Dimension
# *   Bowler_match_SK - Surrogate Key from Player_match Dimension
# *   Bowler_match_SK - Surrogate Key from Player_match Dimension

# %% [markdown]
# QUESTIONS
# 1.      We donot need the penalty in it, so how can we delete it ?
# 2.  How to determine number of rows and columns ?
# 3. What is the maximum number of extras runs ?
# 4. How can we determine number of runs scored on a particular date ?
# 5. What is the minimum number of legbyes ?
# 6. What are the number of bowler wickets with respective to the match date ?
# 7. How can we determine number of wides on particular date of a match ?
# 8. What is the maximum number of no balls ?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mm

# %%
h=pd.read_excel('Ball_By_Ball.xlsx')
h
# Out:
#         MatcH_id  Over_id  Ball_id  ...  Keeper_Catch Player_out_sk MatchDateSK
# 0         598028       15        6  ...             0             0    20130420
# 1         598028       14        1  ...             0             0    20130420
# 2         598028       14        2  ...             0             0    20130420
# 3         598028       14        3  ...             0             0    20130420
# 4         598028       14        4  ...             0             0    20130420
# ...          ...      ...      ...  ...           ...           ...         ...
# 150446    598028       15        1  ...             0             0    20130420
# 150447    598028       15        2  ...             0             0    20130420
# 150448    598028       15        3  ...             0             0    20130420
# 150449    598028       15        4  ...             0             0    20130420
# 150450    598028       15        5  ...             0             0    20130420
#
# ...

# %%
h.isnull().sum()
# Out:
# MatcH_id                         0
# Over_id                          0
# Ball_id                          0
# Innings_No                       0
# Team_Batting                     0
# Team_Bowling                     0
# Striker_Batting_Position     13861
# Extra_Type                       0
# Runs_Scored                      0
# Extra_runs                       0
# Wides                            0
# Legbyes                          0
# Byes                             0
# Noballs                          0
# Penalty                          0
# Bowler_Extras                    0
# Out_type                         0
# Caught                           0
# Bowled                           0
# Run_out                          0
# LBW                              0
# Retired_hurt                     0
# Stumped                          0
# caught_and_bowled                0
# hit_wicket                       0
# ObstructingFeild                 0
# Bowler_Wicket                    0
# ...

# %%
x=h.columns.values.tolist()
x.remove('Player_Out')
x.remove('Fielders')
x.remove('Striker_Batting_Position')
h=h[x]
h.isnull().sum()
# Out:
# MatcH_id               0
# Over_id                0
# Ball_id                0
# Innings_No             0
# Team_Batting           0
# Team_Bowling           0
# Extra_Type             0
# Runs_Scored            0
# Extra_runs             0
# Wides                  0
# Legbyes                0
# Byes                   0
# Noballs                0
# Penalty                0
# Bowler_Extras          0
# Out_type               0
# Caught                 0
# Bowled                 0
# Run_out                0
# LBW                    0
# Retired_hurt           0
# Stumped                0
# caught_and_bowled      0
# hit_wicket             0
# ObstructingFeild       0
# Bowler_Wicket          0
# Match_Date             0
# Season                 0
# Striker                0
# Non_Striker            0
# Bowler                 0
# Striker_match_SK       0
# StrikerSK              0
# NonStriker_match_SK    0
# NONStriker_SK          0
# Fielder_match_SK       0
# Fielder_SK             0
# ...

# %%
h.dtypes
# Out:
# MatcH_id                int64
# Over_id                 int64
# Ball_id                 int64
# Innings_No              int64
# Team_Batting           object
# Team_Bowling           object
# Extra_Type             object
# Runs_Scored             int64
# Extra_runs              int64
# Wides                   int64
# Legbyes                 int64
# Byes                    int64
# Noballs                 int64
# Penalty                 int64
# Bowler_Extras           int64
# Out_type               object
# Caught                  int64
# Bowled                  int64
# Run_out                 int64
# LBW                     int64
# Retired_hurt            int64
# Stumped                 int64
# caught_and_bowled       int64
# hit_wicket              int64
# ObstructingFeild        int64
# Bowler_Wicket           int64
# Match_Date             object
# Season                  int64
# Striker                 int64
# Non_Striker             int64
# Bowler                  int64
# ...

# %%
h.mean()
# Out:
# MatcH_id               6.362075e+05
# Over_id                1.014270e+01
# Ball_id                3.616639e+00
# Innings_No             1.482190e+00
# Runs_Scored            1.222199e+00
# Extra_runs             6.899256e-02
# Wides                  3.750058e-02
# Legbyes                2.223315e-02
# Byes                   4.885311e-03
# Noballs                4.340284e-03
# Penalty                3.323341e-05
# Bowler_Extras          4.184087e-02
# Caught                 2.906594e-02
# Bowled                 9.185715e-03
# Run_out                5.018245e-03
# LBW                    3.024240e-03
# Retired_hurt           5.982014e-05
# Stumped                1.615144e-03
# caught_and_bowled      1.402450e-03
# hit_wicket             5.982014e-05
# ObstructingFeild       6.646682e-06
# Bowler_Wicket          4.435331e-02
# Season                 2.012483e+03
# Striker                1.365370e+02
# Non_Striker            1.356234e+02
# Bowler                 1.940871e+02
# ...

# %%
h.median()
# Out:
# MatcH_id                 548382.0
# Over_id                      10.0
# Ball_id                       4.0
# Innings_No                    1.0
# Runs_Scored                   1.0
# Extra_runs                    0.0
# Wides                         0.0
# Legbyes                       0.0
# Byes                          0.0
# Noballs                       0.0
# Penalty                       0.0
# Bowler_Extras                 0.0
# Caught                        0.0
# Bowled                        0.0
# Run_out                       0.0
# LBW                           0.0
# Retired_hurt                  0.0
# Stumped                       0.0
# caught_and_bowled             0.0
# hit_wicket                    0.0
# ObstructingFeild              0.0
# Bowler_Wicket                 0.0
# Season                     2012.0
# Striker                      96.0
# Non_Striker                  96.0
# Bowler                      174.0
# Striker_match_SK          19672.0
# ...

# %%
h.mode()
# Out:
#    MatcH_id  Over_id  Ball_id  ...  Keeper_Catch Player_out_sk MatchDateSK
# 0  392195.0      1.0      1.0  ...           0.0           0.0  20090423.0
# 1       NaN      NaN      NaN  ...           NaN           NaN         NaN
#
# [2 rows x 45 columns]

# %%
h.var()
# Out:
# MatcH_id               5.492568e+10
# Over_id                3.219717e+01
# Ball_id                3.267557e+00
# Innings_No             2.517715e-01
# Runs_Scored            2.541827e+00
# Extra_runs             1.219798e-01
# Wides                  6.625737e-02
# Legbyes                4.004407e-02
# Byes                   1.305024e-02
# Noballs                5.278603e-03
# Penalty                1.661671e-04
# Bowler_Extras          7.121045e-02
# Caught                 2.822130e-02
# Bowled                 9.101398e-03
# Run_out                4.993096e-03
# LBW                    3.015114e-03
# Retired_hurt           5.981696e-05
# Stumped                1.612546e-03
# caught_and_bowled      1.400492e-03
# hit_wicket             5.981696e-05
# ObstructingFeild       6.646682e-06
# Bowler_Wicket          4.238638e-02
# Season                 7.633490e+00
# Striker                1.452850e+04
# Non_Striker            1.441690e+04
# Bowler                 1.768872e+04
# ...

# %%
h.var(ddof=1)
# Out:
# MatcH_id               5.492568e+10
# Over_id                3.219717e+01
# Ball_id                3.267557e+00
# Innings_No             2.517715e-01
# Runs_Scored            2.541827e+00
# Extra_runs             1.219798e-01
# Wides                  6.625737e-02
# Legbyes                4.004407e-02
# Byes                   1.305024e-02
# Noballs                5.278603e-03
# Penalty                1.661671e-04
# Bowler_Extras          7.121045e-02
# Caught                 2.822130e-02
# Bowled                 9.101398e-03
# Run_out                4.993096e-03
# LBW                    3.015114e-03
# Retired_hurt           5.981696e-05
# Stumped                1.612546e-03
# caught_and_bowled      1.400492e-03
# hit_wicket             5.981696e-05
# ObstructingFeild       6.646682e-06
# Bowler_Wicket          4.238638e-02
# Season                 7.633490e+00
# Striker                1.452850e+04
# Non_Striker            1.441690e+04
# Bowler                 1.768872e+04
# ...

# %%
h.describe()
# Out:
#            MatcH_id        Over_id  ...  Player_out_sk   MatchDateSK
# count  1.504510e+05  150451.000000  ...  150451.000000  1.504510e+05
# mean   6.362075e+05      10.142704  ...       1.100704  2.012529e+07
# std    2.343623e+05       5.674255  ...      20.404263  2.763159e+04
# min    3.359870e+05       1.000000  ...      -1.000000  2.008042e+07
# 25%    4.191540e+05       5.000000  ...       0.000000  2.010041e+07
# 50%    5.483820e+05      10.000000  ...       0.000000  2.012052e+07
# 75%    8.297420e+05      15.000000  ...       0.000000  2.015042e+07
# max    1.082650e+06      20.000000  ...     496.000000  2.017052e+07
#
# [8 rows x 40 columns]

# %%
mm.figure(figsize=(10,7))
z=h["Runs_Scored"]
mm.hist(z, bins=10,color="black")
mm.title("Runs_Scored")
mm.xlabel("Runs")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["BattingTeam_SK"]
mm.hist(z, bins=15,color="black")
mm.title("BattingTeam_SK")
mm.xlabel("Position")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["MatcH_id"]
mm.hist(z, bins=5,color="black")
mm.title("MatcH_id")
mm.xlabel("Count")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["Innings_No"]
mm.hist(z, bins=10,color="black")
mm.title("Innings_No")
mm.xlabel("count")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["Extra_runs"]
mm.hist(z, bins=15,color="black")
mm.title("Extra_runs")
mm.xlabel("Runs")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["Run_out"]
mm.hist(z, bins=3,color="black")
mm.title("Run_out")
mm.xlabel("Runs")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["Season"]
mm.hist(z, bins=15,color="black")
mm.title("Season")
mm.xlabel("season")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["Bowler"]
mm.hist(z, bins=15,color="black")
mm.title("Bowler")
mm.xlabel("num of balls")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
mm.figure(figsize=(10,7))
z=h["Bowler_match_SK"]
mm.hist(z, bins=26,color="black")
mm.title("Bowler_match_SK")
mm.xlabel("count")
mm.ylabel("Units")
# Out:
# Text(0, 0.5, 'Units')

# %%
# answer for 1st question
del h['Penalty']
h
# Out:
#         MatcH_id  Over_id  Ball_id  ...  Keeper_Catch Player_out_sk MatchDateSK
# 0         598028       15        6  ...             0             0    20130420
# 1         598028       14        1  ...             0             0    20130420
# 2         598028       14        2  ...             0             0    20130420
# 3         598028       14        3  ...             0             0    20130420
# 4         598028       14        4  ...             0             0    20130420
# ...          ...      ...      ...  ...           ...           ...         ...
# 150446    598028       15        1  ...             0             0    20130420
# 150447    598028       15        2  ...             0             0    20130420
# 150448    598028       15        3  ...             0             0    20130420
# 150449    598028       15        4  ...             0             0    20130420
# 150450    598028       15        5  ...             0             0    20130420
#
# ...

# %%
# answer for 2nd question
h.shape
# Out:
# (150451, 44)

# %%
# answer for 3rd question
h["Extra_runs"].max()
# Out:
# 5

# %%
# answer for 4th question
h.loc[h["Match_Date"]=="2013-04-20",:].loc[:,["Runs_Scored"]]
# Out:
#         Runs_Scored
# 0                 4
# 1                 1
# 2                 1
# 3                 1
# 4                 0
# ...             ...
# 150446            1
# 150447            2
# 150448            4
# 150449            0
# 150450            0
#
# [469 rows x 1 columns]

# %%
# answer for 5th question
h["Legbyes"].min()
# Out:
# 0

# %%
# answer for 6th question
h.groupby(["Match_Date","Bowler_Wicket"]).size()
# Out:
# Match_Date  Bowler_Wicket
# 2008-04-18  0                213
#             1                 12
# 2008-04-19  0                451
#             1                 16
# 2008-04-20  0                462
#                             ...
# 2017-05-17  1                  9
# 2017-05-19  0                193
#             1                 14
# 2017-05-21  0                237
#             1                 11
# Length: 900, dtype: int64

# %%
# answer for 7th question
h.loc[h["Match_Date"]=="	2013-04-20",:].loc[:,["Wides"]]
# Out:
#         Wides
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 150446      0
# 150447      0
# 150448      0
# 150449      0
# 150450      0
#
# [469 rows x 1 columns]

# %%
# answer for 8th question
h["Noballs"].max()
# Out:
# 5
